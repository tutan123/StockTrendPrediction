# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from numpy import row_stack,column_stack
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, WeekdayLocator, DayLocator, MONDAY,YEARLY
# from mpl_finance import quotes_historical_yahoo_ohlc, candlestick_ohlc
from matplotlib.pylab import date2num

import tushare as ts
import datetime
import time

# %%
df = pd.read_csv('./cjpl/20160701_20160801.csv', sep=',',header = 0, usecols=range(8))

# %%
df.head(20)
# Out:
#                  页面信息                        评论标题  发表作者                 发表时间  \
# 0   ['page_2360', 12]   中国今年调减玉米种植面积3000万亩 13年来首次  财经评论  2016-07-31 23:52:03
# 1   ['page_2360', 13]       科研项目资金改革解读：打酱油的钱可以买醋了  财经评论  2016-07-31 23:37:01
# 2   ['page_2360', 14]           A股交易策略：战略性配置绩优价值股  财经评论  2016-07-31 23:20:58
# 3   ['page_2360', 15]    中国将发SDR计价债券 IMF发言人回应市场疑惑  财经评论  2016-07-31 22:48:53
# 4   ['page_2360', 16]    安徽放大招控楼市：买地首付款最少50% 闲置两年  财经评论  2016-07-31 22:34:52
# 5   ['page_2360', 17]      牛散出没请注意 赵建平坚守这家上市公司三年赚  财经评论  2016-07-31 22:19:51
# 6   ['page_2360', 18]     八月首周新股发行猛增至9只 抽奖靠运气不妨关注  财经评论  2016-07-31 22:04:51
# 7   ['page_2360', 19]      中报行情要不要跟一波？41股业绩预增超10倍  财经评论  2016-07-31 21:51:50
# 8   ['page_2360', 20]     市值配售尽情嗨：8月首周可打9只新股 周三有三  财经评论  2016-07-31 21:47:49
# 9   ['page_2360', 21]    最多一日发9封问询函 近一周29家上市公司被交易  财经评论  2016-07-31 21:40:47
# 10  ['page_2360', 22]      从爱理不理到高攀不起 绩优股弱市成功集体逆袭  财经评论  2016-07-31 21:36:48
# ...

# %%
df[['发表时间','评论标题']].head()
# Out:
#                   发表时间                       评论标题
# 0  2016-07-31 23:52:03  中国今年调减玉米种植面积3000万亩 13年来首次
# 1  2016-07-31 23:37:01      科研项目资金改革解读：打酱油的钱可以买醋了
# 2  2016-07-31 23:20:58          A股交易策略：战略性配置绩优价值股
# 3  2016-07-31 22:48:53   中国将发SDR计价债券 IMF发言人回应市场疑惑
# 4  2016-07-31 22:34:52   安徽放大招控楼市：买地首付款最少50% 闲置两年

# %%
new_df = df[['发表时间','评论标题']].copy()

new_df.to_csv('title20160701_20160801.csv',index = False)

# %%
df20160401 = pd.read_csv('./cjpl/20160401_20160501.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20160501 = pd.read_csv('./cjpl/20160501_20160601.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20160601 = pd.read_csv('./cjpl/20160601_20160701.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20160701 = pd.read_csv('./cjpl/20160701_20160801.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20160801 = pd.read_csv('./cjpl/20160801_20160901.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20160901 = pd.read_csv('./cjpl/20160901_20161001.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20161001 = pd.read_csv('./cjpl/20161001_20161101.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20161101 = pd.read_csv('./cjpl/20161101_20161201.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20161201 = pd.read_csv('./cjpl/20161201_20170101.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]

# %%
df20160401[['发表时间','评论标题']].to_csv('df20160401.csv',index = False)
df20160501[['发表时间','评论标题']].to_csv('df20160501.csv',index = False)
df20160601[['发表时间','评论标题']].to_csv('df20160601.csv',index = False)
df20160701[['发表时间','评论标题']].to_csv('df20160701.csv',index = False)
df20160801[['发表时间','评论标题']].to_csv('df20160801.csv',index = False)
df20160901[['发表时间','评论标题']].to_csv('df20160901.csv',index = False)
df20161001[['发表时间','评论标题']].to_csv('df20161001.csv',index = False)
df20161101[['发表时间','评论标题']].to_csv('df20161101.csv',index = False)
df20161201[['发表时间','评论标题']].to_csv('df20161201.csv',index = False)

# %%
df20170101 = pd.read_csv('./cjpl/20170101_20170201.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170201 = pd.read_csv('./cjpl/20170201_20170301.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170301 = pd.read_csv('./cjpl/20170301_20170401.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170401 = pd.read_csv('./cjpl/20170401_20170501.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170501 = pd.read_csv('./cjpl/20170501_20170601.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170601 = pd.read_csv('./cjpl/20170601_20170701.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170701 = pd.read_csv('./cjpl/20170701_20170801.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170801 = pd.read_csv('./cjpl/20170801_20170901.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]
df20170901 = pd.read_csv('./cjpl/20170901_20171001.csv', sep=',',header = 0, usecols=range(8)).iloc[::-1]

# %%
df20170101[['发表时间','评论标题']].to_csv('df20170101.csv',index = False)
df20170201[['发表时间','评论标题']].to_csv('df20170201.csv',index = False)
df20170301[['发表时间','评论标题']].to_csv('df20170301.csv',index = False)
df20170401[['发表时间','评论标题']].to_csv('df20170401.csv',index = False)
df20170501[['发表时间','评论标题']].to_csv('df20170501.csv',index = False)
df20170601[['发表时间','评论标题']].to_csv('df20170601.csv',index = False)
df20170701[['发表时间','评论标题']].to_csv('df20170701.csv',index = False)
df20170801[['发表时间','评论标题']].to_csv('df20170801.csv',index = False)
df20170901[['发表时间','评论标题']].to_csv('df20170901.csv',index = False)

# %%
combine_df = pd.concat([df20160401,df20160501,df20160601,df20160701,df20160801,df20160901,df20161001,
                        df20161101,df20161201,df20170101,df20170201,df20170301,df20170401,df20170501,df20170601,
                       df20170701,df20170801,df20170901],axis=0,ignore_index=True)

# %%
combine_df[['发表时间','评论标题']].to_csv('combine_df.csv',index = False)
