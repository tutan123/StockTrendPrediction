# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('1-Result-Vanke-from-20110701-to-20181118.csv')
df2 = pd.read_csv('1-Result-Vanke-from-20110701-to-20181118.csv')
df3 = pd.read_csv('1-Result-Vanke-from-20110701-to-20181118.csv')
df4 = pd.read_csv('1-Result-Vanke-from-20110701-to-20181118.csv')
df5 = pd.read_csv('1-Result-Vanke-from-20110701-to-20181118.csv')
df1.head()
# Out:
#      ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0  601318.SH    20170428  37.90  38.07  37.61  37.96      37.82    0.14
# 1  601318.SH    20170502  37.80  38.38  37.80  37.91      37.96   -0.05
# 2  601318.SH    20170503  37.95  38.28  37.82  38.00      37.91    0.09
# 3  601318.SH    20170504  37.95  38.10  37.73  37.82      38.00   -0.18
# 4  601318.SH    20170505  37.70  37.86  37.20  37.26      37.82   -0.56
#
#    pct_chg        vol       amount  ave_change  pred_ave_change  real_trend  \
# 0     0.37  678663.87  2568647.819   -0.046667        -0.007615           1
# 1    -0.13  619325.39  2359210.184   -0.216667        -0.070226           0
# 2     0.24  505383.86  1920918.772   -0.070000        -0.216266           0
# 3    -0.47  548573.55  2080732.893    0.056667        -0.002267           0
# 4    -1.48  623979.60  2337681.712    0.860000         0.210840           1
#
#    pred_trend
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
real_trend = df['real_trend']
pred_trend = df['pred_trend']

# %%
xlims = (0,len(real_trend))
ylims = (0, 300)

# %%
def plot_renko(data, brick_size):
    fig = plt.figure(figsize=(20,10))
    fig.clf()
    axes = fig.gca()   
    prev_num = 0
    for index, number in enumerate(data):
#         print(index, number)
        if number == 1:
            facecolor='red'
        elif number == 0:
            facecolor='blue'
        else:
            facecolor='green'

        prev_num += number

        renko = Rectangle(
            (index, prev_num * brick_size+100), 1, brick_size,
            facecolor=facecolor, alpha=0.5
        )
        axes.add_patch(renko)
    plt.xlim(xlims)
    plt.ylim(ylims)
#     plt.show()

# %%
# %matplotlib qt
fig = plt.figure(figsize=(20,10))
fig.clf()
axes = fig.gca()   
prev_num = 0
data = real_trend
brick_size = 2
for index, number in enumerate(data):
#         print(index, number)
    if number == 1:
        facecolor='red'
    elif number == 0:
        facecolor='blue'
    else:
        facecolor='green'

    prev_num += number

    renko = Rectangle(
        (index, prev_num * brick_size+200), 1, brick_size,
        facecolor=facecolor, alpha=0.5
    )
    axes.add_patch(renko)

prev_num = 0
data = pred_trend
brick_size = 2
for index, number in enumerate(data):
#         print(index, number)
    if number == 1:
        facecolor='red'
    elif number == 0:
        facecolor='blue'
    else:
        facecolor='green'

    prev_num += number

    renko = Rectangle(
        (index, prev_num * brick_size+130), 1, brick_size,
        facecolor=facecolor, alpha=0.5
    )
    axes.add_patch(renko)    

    
prev_num = 0
data = svr_pred_trend
brick_size = 2
for index, number in enumerate(data):
#         print(index, number)
    if number == 1:
        facecolor='red'
    elif number == 0:
        facecolor='blue'
    else:
        facecolor='green'

    prev_num += number

    renko = Rectangle(
        (index, prev_num * brick_size+20), 1, brick_size,
        facecolor=facecolor, alpha=0.5
    )
    axes.add_patch(renko)   
    
# prev_num = 0
# data = random_trend
# brick_size = 2
# for index, number in enumerate(data):
# #         print(index, number)
#     if number == 1:
#         facecolor='red'
#     elif number == 0:
#         facecolor='blue'
#     else:
#         facecolor='green'

#     prev_num += number

#     renko = Rectangle(
#         (index, prev_num * brick_size+100), 1, brick_size,
#         facecolor=facecolor, alpha=0.5
#     )
#     axes.add_patch(renko)   
plt.tick_params(axis='both', which='major', labelsize=30)
# plt.tick_params(axis='both', which='minor', labelsize=8)
plt.xlabel('Days', fontsize=40)
plt.ylabel('Trend Prediction', fontsize=40)
plt.xlim(xlims)
plt.ylim(ylims)
# Out:
# (0, 300)

# %%
df = pd.read_csv('Result-Pingan-from-20110101-to-20181118.csv')
df.head()
# Out:
#      ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0  601318.SH    20170428  37.90  38.07  37.61  37.96      37.82    0.14
# 1  601318.SH    20170502  37.80  38.38  37.80  37.91      37.96   -0.05
# 2  601318.SH    20170503  37.95  38.28  37.82  38.00      37.91    0.09
# 3  601318.SH    20170504  37.95  38.10  37.73  37.82      38.00   -0.18
# 4  601318.SH    20170505  37.70  37.86  37.20  37.26      37.82   -0.56
#
#    pct_chg        vol       amount  ave_change  pred_ave_change  real_trend  \
# 0     0.37  678663.87  2568647.819   -0.046667        -0.007615           1
# 1    -0.13  619325.39  2359210.184   -0.216667        -0.070226           0
# 2     0.24  505383.86  1920918.772   -0.070000        -0.216266           0
# 3    -0.47  548573.55  2080732.893    0.056667        -0.002267           0
# 4    -1.48  623979.60  2337681.712    0.860000         0.210840           1
#
#    pred_trend
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
real_trend = df['real_trend']
pred_trend = df['pred_trend']

# %%
temp_list = []
temp_df =  real_trend - pred_trend
for i in range(0, len(temp_df)):
    temp_list.append([i, temp_df[i]])

# %%
# %matplotlib qt
plt.clf()
# plt.figure()
plt.scatter( *zip(*temp_list), )
# plt.scatter(real_df.index.values, pred_df[0],color='blue', marker='^')
# plt.scatter(real_df.index.values, real_df[0],color='red', marker='.')
plt.title('Trend Prediction Accuracy of 601318SH' )
plt.xlabel('Days')
plt.ylabel('Trend Prediction')
plt.show()

# %%
temp_list = []
temp_df =  real_trend[0] - pred_df[0]
for i in range(0, len(temp_df)):
    temp_list.append([i, temp_df[i]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c2d2ae467e3b> in <module>()
#       1 temp_list = []
# ----> 2 temp_df =  real_trend[0] - pred_df[0]
#       3 for i in range(0, len(temp_df)):
#       4     temp_list.append([i, temp_df[i]])
#
# NameError: name 'pred_df' is not defined
